# %% [markdown]
# # ⚙️ JVM & Translog Optimization Demo
#
# This notebook demonstrates OpenSearch JVM memory configuration and translog optimization for improved ingestion performance.
#
# ## 🎯 What We'll Learn:
# - JVM heap sizing (50% of available memory)
# - Translog flush threshold optimization (25% of heap)
# - Memory monitoring and analysis
# - Performance impact measurement
#
# ```mermaid
# graph TD
#     A[💻 System Memory 16GB] --> B[🔧 JVM Heap 8GB]
#     B --> C[📝 Translog 2GB]
#     C --> D[⚡ Faster Flushes]
#
#     E[📊 Default Settings] --> F[🐌 512MB Translog]
#     F --> G[🔄 Frequent Flushes]
#     G --> H[💥 Performance Impact]
#
#     D --> I[🎯 Optimized Performance]
#     H --> J[⚠️ Degraded Performance]
#
#     style B fill:#c8e6c9
#     style C fill:#fff3e0
#     style I fill:#f3e5f5
#     style J fill:#ffebee
# ```

# %% [markdown]
# ## 🐳 Step 1: Create Optimized Docker Compose
#
# First, let's create a specialized docker-compose file with optimized JVM settings:
