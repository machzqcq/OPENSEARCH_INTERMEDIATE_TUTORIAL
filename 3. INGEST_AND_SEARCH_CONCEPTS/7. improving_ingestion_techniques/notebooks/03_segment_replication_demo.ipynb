# %% [markdown]
# # 🔄 Segment Replication Optimization Demo
#
# This notebook demonstrates the performance benefits of segment replication vs document replication in OpenSearch.
#
# ## 🎯 What We'll Learn:
# - Document replication vs segment replication
# - CPU and network usage patterns
# - Performance impact on ingestion
# - When to use each strategy
#
# ```mermaid
# graph TD
#     subgraph "Document Replication (Default)"
#         A1[📄 Primary Shard] --> B1[🔄 Process Document]
#         B1 --> C1[📨 Send Raw Document]
#         C1 --> D1[🔄 Replica Processes Again]
#         D1 --> E1[💻 2x CPU Usage]
#     end
#
#     subgraph "Segment Replication (Optimized)"
#         A2[📄 Primary Shard] --> B2[🔄 Process Document]
#         B2 --> C2[📦 Send Processed Segment]
#         C2 --> D2[⚡ Replica Uses Directly]
#         D2 --> E2[💻 Reduced CPU Usage]
#     end
#
#     style E2 fill:#c8e6c9
#     style E1 fill:#ffebee
#     style C2 fill:#fff3e0
#     style D2 fill:#e3f2fd
# ```
